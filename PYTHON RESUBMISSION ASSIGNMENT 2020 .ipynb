# %% [markdown]
# # <font color='maroon'>PYTHON RESUBMISSION ASSIGNMENT 2020 </font>

# %% [markdown]
# ## <font color='blue'>Command Line Interface (CLI)</font>

# %% [markdown]
# ### <font color='maroon'>PQ 3.1.1.1</font>
# * What is Bash? Check all that apply.
#     * Bourne Again shell correct
#     * A text-based program correct
#     * A way to perform tasks on your computer using typed commands correct

# %% [markdown]
# ### <font color='maroon'>PQ 3.1.4.1</font>
# * What does cd .. do?
#     * Go up one level from your current working directory
#
# ### <font color='maroon'>PQ 3.1.4.2</font>
# * Which two commands are guaranteed to take you back to your home directory? Select all that apply.
#     * cd
#     * cd ~
#
# ### <font color='maroon'>PQ 3.1.4.3</font>
# * What command do you type to see where you are in your system?
#     * pwd

# %% [markdown]
# ### <font color='maroon'>PQ 3.1.6.1</font>
# * Which command would you use to to list out entries with additional file information displayed?
#     * ls-l
#
# ### <font color='maroon'>PQ 3.1.6.2</font>
# * What is the command to list out entries in reverse order on one line per entry?
#     * ls -r -1
#
# ### <font color='maroon'>PQ 3.1.6.3</font>
# * Which of these commands displays the owner; permissions; and date /time of last modification of last file?
#     * ls -l
#     * ls -o
#
# ### <font color='maroon'>PQ 3.1.6.4</font>
# * When you print out a long listing format of entries, if there is a letter "d" at the beginning of an entry what does the letter d mean?
#     * it means thats a directory
#
# ### <font color='maroon'>PQ 3.1.6.1</font>
# * If you wanted a comma separated list of entries that are reverse sorted, what command would you use?
#     * ls-r-m

# %% [markdown]
# ### <font color='maroon'>PQ 3.1.8.1</font>
# * Which command creates a new file: My New File?
#     * touch "My New File"
#
# ### <font color='maroon'>PQ 3.1.8.2</font>
# * What command would you write to create two new folders: 1. New Folder One 2. FolderTwo
#     * mkdir "New Folder One" "FolderTwo"
#
# ### <font color='maroon'>PQ 3.1.8.3</font>
# * Which command can be used to rename a directory?
#     * mv
#
# ### <font color='maroon'>PQ 3.1.8.4</font>
# * What does this command do? rmdir my folder
#     * Removes one directory called "my folder"

# %% [markdown]
# ### <font color='maroon'>PQ 3.1.10.1</font>
# * What's the keyboard shortcut for the clear command?
#     * ctrl l
#
# ### <font color='maroon'>PQ 3.1.10.2</font>
# 1 point possible (graded)
# * Which commands help you find previously entered commands?
#     * history command
#     * The up and down arrow keys
#     * ctrl + r

# %% [markdown]
# ### <font color='maroon'>PCC 3.1.12.1</font>
# * What command would you use to rename a directory?
#     * mv
#
# ### <font color='maroon'>PCC 3.1.12.2</font>
# * What command can you write that will take you back to your home directory in a single command?
#     * cd
#
# ### <font color='maroon'>PCC 3.1.12.3</font>
# * How would you use bash to create a new python file called, myNewFile?
#     * touch myNewFile.py
#
#
# ### <font color='maroon'>PCC 3.1.12.4</font>
# * When you use bash to create new files, if you don't specify the file extension, what type of file is created by default?
#     * .txt - Text File
#
# ### <font color='maroon'>PCC 3.1.12.5</font>
# * What is the keyboard shortcut to stop or erase the current command?
#     * ctrl c
#
# ### <font color='maroon'>PCC 3.1.12.6</font>
# * How do you auto-complete filenames and directories in Bash?
#     * tab key
#
# ### <font color='maroon'>PCC 3.1.12.7</font>
# * What is the keyboard shortcut to go the beginning of the line in a bash shell?
#     * ctrl + a
#
# ### <font color='maroon'>PCC 3.1.12.8</font>
# * How would you create three new files with one command?
#     * touch file1 file2 file3
#     * touch 'file one' file2 'file3'
#
# ### <font color='maroon'>PCC 3.1.12.9</font>
# * What root command do you use to display the contents of a directory?
#     * ls

# %% [markdown]
# ### <font color='maroon'>PCC 4.2.4.1</font>
# * What are the three different types of version control?
#     * Local Version Control
#     * Centralized Version Control
#     * Distributed Version Control
#
# ### <font color='maroon'>PCC 4.2.4.2</font>
# * What are the main benefits of version control?
#     * Long-term Change History
#     * Branching and Merging
#     * Traceability
#
# ### <font color='maroon'>PCC 4.2.4.3</font>
# * What's the best way to describe the folder structure used for a project?
#     * A File Tree

# %% [markdown]
# ### <font color='maroon'>PCC 4.3.3.1</font>
# * Who is responsible for the creation of Git?
#     * Linus Torvalds
#
# ### <font color='maroon'>PCC 4.3.3.2</font>
# * Which statement is the most accurate?
#     * Every developer's working copy contains the full version history when using git.
#
# ### <font color='maroon'>PCC 4.3.3.3</font>
# * What one word would you use to describe the way that git thinks about its data?
#     * snapshot
#
# ### <font color='maroon'>PCC 4.3.3.4</font>
# * Which of the following statements are true?
#     * Most operations in Git only need local files and resources to operate.
#     * Each Git repository contains an entire project history.
#     * Everything in Git is stored and referenced by a checksum, also know as a hash.
#
# ### <font color='maroon'>PCC 4.3.3.5</font>
# What are the three states of Git?
# Committed
# Deleted
# Modified
# Staged

# %% [markdown]
# ## <font color='blue'>Summative</font>

# %% [markdown]
# ## <font color='maroon'>Problem 1</font>
# **You have been asked to generate a dummy dataset that you can use to prove your solutions work with.**
#
# **ACCEPTANCE CRITERIA**
# 1. The order of the objects must be sequential, ( ie. 1,2,3...32. ) since each number references a different pipeline region.
# 2. Your generated dataset needs to return a single set of data, that has 32 entries, with each entry returning 16 floats.
# 3. The 16 floats returned will be between 0 and 1

# %% [markdown]
# ## <font color='blue'>Solution</font>

# %%
#import libraries
import numpy as np
import pandas as pd
data=[]
df = pd.DataFrame(data, columns=['Sensor1', 'Sensor2', 'Sensor3', 'Sensor4', 'Sensor5', 'Sensor6', 'Sensor7', 'Sensor8', 'Sensor9', 'Sensor10', 'Sensor11', 'Sensor12', 'Sensor13', 'Sensor14', 'Sensor15', 'Sensor16', 'Sensor17', 'Sensor18', 'Sensor19', 'Sensor20', 'Sensor21', 'Sensor22', 'Sensor23', 'Sensor24', 'Sensor25', 'Sensor26', 'Sensor27', 'Sensor28', 'Sensor29', 'Sensor30', 'Sensor31', 'Sensor32']).astype(float)

# %%
if df.empty:
    print('DataFrame is empty!')
# Out:
# DataFrame is empty!

# %%
#import libraries
import numpy as np
import pandas as pd

#randomly generate data with 16 rows and 32 columns
data = np.random.rand(16,32)

#add the data to respective columns and ensure datatype is float
df = pd.DataFrame(data, columns=['Sensor1', 'Sensor2', 'Sensor3', 'Sensor4', 'Sensor5', 'Sensor6', 'Sensor7', 'Sensor8', 'Sensor9', 'Sensor10', 'Sensor11', 'Sensor12', 'Sensor13', 'Sensor14', 'Sensor15', 'Sensor16', 'Sensor17', 'Sensor18', 'Sensor19', 'Sensor20', 'Sensor21', 'Sensor22', 'Sensor23', 'Sensor24', 'Sensor25', 'Sensor26', 'Sensor27', 'Sensor28', 'Sensor29', 'Sensor30', 'Sensor31', 'Sensor32']).astype(float)

print(df)
print(df.dtypes)
# Out:
#      Sensor1   Sensor2   Sensor3   Sensor4   Sensor5   Sensor6   Sensor7  \
# 0   0.952088  0.533663  0.559658  0.480820  0.344662  0.527627  0.687098
# 1   0.760006  0.152924  0.250658  0.207366  0.944915  0.333430  0.838590
# 2   0.858590  0.123996  0.508982  0.408712  0.119231  0.954747  0.886900
# 3   0.737013  0.927388  0.801826  0.377784  0.241458  0.342120  0.896900
# 4   0.837985  0.014583  0.617996  0.679102  0.560744  0.891439  0.187960
# 5   0.924228  0.531831  0.089605  0.334769  0.930683  0.754885  0.022926
# 6   0.351845  0.153277  0.631922  0.566675  0.383056  0.697038  0.567123
# 7   0.119330  0.334444  0.525368  0.160338  0.351810  0.581938  0.464359
# 8   0.394472  0.682543  0.709075  0.998976  0.836019  0.373658  0.970877
# 9   0.853944  0.814179  0.944656  0.288184  0.609276  0.010441  0.580327
# 10  0.801490  0.759603  0.720942  0.750708  0.942733  0.084980  0.811186
# 11  0.381005  0.906231  0.106120  0.574188  0.645242  0.862292  0.229211
# ...

# %% [markdown]
# ## <font color='maroon'>Problem 2</font>
#
# **Once you have your dataset to work with you will need to show that you can store this data with every iteration of the data set so no data is lost.**
#
# **ACCEPTANCE CRITERIA**
# 1. Every time your data set is generated the output should be stored and saved
# 2. For a challenge you could try to write the data to a file
# 3. New data should not overwrite historical data
# 4. For an extra challenge you can try to date and time stamp each interval of data collection

# %% [markdown]
# ## <font color='blue'>Solution</font>

# %%
#add file path
import os.path

filename = '/Users/vivianopondoh/AIIP/Python_Summative/sensor_data.csv'
file_exists = os.path.isfile(filename)

#check if file exists before adding header & set mode to append new data
if file_exists:
        df.to_csv (r'/Users/vivianopondoh/AIIP/Python_Summative/sensor_data.csv', mode='a', index = False, header=False)
else:
        df.to_csv (r'/Users/vivianopondoh/AIIP/Python_Summative/sensor_data.csv', mode='a', index = False, header=True)

# %%
df.head()
# Out:
#     Sensor1   Sensor2   Sensor3   Sensor4   Sensor5   Sensor6   Sensor7  \
# 0  0.952088  0.533663  0.559658  0.480820  0.344662  0.527627  0.687098
# 1  0.760006  0.152924  0.250658  0.207366  0.944915  0.333430  0.838590
# 2  0.858590  0.123996  0.508982  0.408712  0.119231  0.954747  0.886900
# 3  0.737013  0.927388  0.801826  0.377784  0.241458  0.342120  0.896900
# 4  0.837985  0.014583  0.617996  0.679102  0.560744  0.891439  0.187960
#
#     Sensor8   Sensor9  Sensor10  ...  Sensor23  Sensor24  Sensor25  Sensor26  \
# 0  0.113230  0.259149  0.230360  ...  0.718622  0.205384  0.123139  0.384953
# 1  0.439380  0.054454  0.982305  ...  0.984041  0.050056  0.265039  0.546991
# 2  0.108637  0.232113  0.374160  ...  0.856595  0.866347  0.162198  0.122535
# 3  0.849200  0.364351  0.890005  ...  0.935784  0.860452  0.619907  0.970953
# 4  0.326822  0.244008  0.685268  ...  0.673914  0.514427  0.881521  0.943878
#
#    Sensor27  Sensor28  Sensor29  Sensor30  Sensor31  Sensor32
# ...

# %% [markdown]
# ## <font color='maroon'>Problem 3</font>
#
# **Write a function that will test the incoming data for possible strings entries**
#
# **ACCEPTANCE CRITERIA**
# 1. Create a copy of a "corrupted" data set containing at least one entry where the value is "err"
# 2. Your function should check for this error
# 3. Convert the string to a numerical value that can be uniquely identified as the error
# 4. Create an error log that records that the error happened and which of the sensors the error occurred with
# 5. For a challenge you can try to date and time stamp the log entries

# %% [markdown]
# ## <font color='blue'>Solution</font>

# %%
#load corrupt file
data_corr = pd.read_csv('sensor_data_err.csv')

# %%
data_corr.head()
# Out:
#     Sensor1   Sensor2   Sensor3   Sensor4   Sensor5   Sensor6   Sensor7  \
# 0  0.746263  0.028628  0.537842  0.654106  0.811672  0.923223  0.430775
# 1  0.471847  0.127478  0.923473  0.787359  0.512601  0.175003  0.489103
# 2  0.930765  0.880325  0.432631  0.202138  0.388268  0.593497  0.246906
# 3  0.937899  0.848473  0.180055  0.146317  0.589465  0.488843  0.833074
# 4  0.478260  0.335792  0.957564  0.971961  0.231893  0.531813  0.421526
#
#     Sensor8   Sensor9     Sensor10  ...  Sensor23  Sensor24  Sensor25  \
# 0  0.207031  0.258660  0.879004107  ...  0.241226  0.218158  0.090962
# 1  0.177194  0.964093  0.750238278  ...  0.422048  0.846530  0.161673
# 2  0.780434  0.294715  0.103262313  ...  0.548245  0.351027  0.661133
# 3  0.198596  0.390394          err  ...  0.266921  0.565948  0.656248
# 4  0.584830  0.325982  0.736688171  ...  0.964450  0.087647  0.603660
#
#    Sensor26  Sensor27  Sensor28  Sensor29  Sensor30  Sensor31  Sensor32
# ...

# %%
# creating and passsing series to new column 
df_corr = pd.DataFrame(data_corr)

# %%
df_corr.dtypes
# Out:
# Sensor1     float64
# Sensor2     float64
# Sensor3     float64
# Sensor4     float64
# Sensor5     float64
# Sensor6     float64
# Sensor7     float64
# Sensor8     float64
# Sensor9     float64
# Sensor10     object
# Sensor11    float64
# Sensor12    float64
# Sensor13    float64
# Sensor14    float64
# Sensor15    float64
# Sensor16    float64
# Sensor17    float64
# Sensor18    float64
# Sensor19    float64
# Sensor20    float64
# Sensor21    float64
# Sensor22    float64
# Sensor23    float64
# Sensor24    float64
# Sensor25    float64
# Sensor26    float64
# Sensor27    float64
# Sensor28    float64
# Sensor29    float64
# Sensor30    float64
# Sensor31    float64
# Sensor32    float64
# dtype: object

# %%
df_corr.applymap(type).eq(str).all()
# Out:
# Sensor1     False
# Sensor2     False
# Sensor3     False
# Sensor4     False
# Sensor5     False
# Sensor6     False
# Sensor7     False
# Sensor8     False
# Sensor9     False
# Sensor10     True
# Sensor11    False
# Sensor12    False
# Sensor13    False
# Sensor14    False
# Sensor15    False
# Sensor16    False
# Sensor17    False
# Sensor18    False
# Sensor19    False
# Sensor20    False
# Sensor21    False
# Sensor22    False
# Sensor23    False
# Sensor24    False
# Sensor25    False
# Sensor26    False
# Sensor27    False
# Sensor28    False
# Sensor29    False
# Sensor30    False
# Sensor31    False
# Sensor32    False
# dtype: bool

# %%
df_corr.applymap(type).eq(str).all()
# Out:
# Sensor1     False
# Sensor2     False
# Sensor3     False
# Sensor4     False
# Sensor5     False
# Sensor6     False
# Sensor7     False
# Sensor8     False
# Sensor9     False
# Sensor10     True
# Sensor11    False
# Sensor12    False
# Sensor13    False
# Sensor14    False
# Sensor15    False
# Sensor16    False
# Sensor17    False
# Sensor18    False
# Sensor19    False
# Sensor20    False
# Sensor21    False
# Sensor22    False
# Sensor23    False
# Sensor24    False
# Sensor25    False
# Sensor26    False
# Sensor27    False
# Sensor28    False
# Sensor29    False
# Sensor30    False
# Sensor31    False
# Sensor32    False
# dtype: bool

# %%
for i, temp in enumerate(sensorData):
    #define threshold variable
    threshold = 0.65
    # Since Python counts from 0 add 1 so machine numbers are accurate
    i = i + 1
    # If
    if temp < threshold:
        print("All OK. Machine {}, Temperature is {}".format(i, temp))
    else:
        print('Danger! Machine {} is above temperature threshold. Temperature is {}'.format(i,temp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-72a9695261e9> in <module>
# ----> 1 for i, temp in enumerate(sensorData):
#       2     #define threshold variable
#       3     threshold = 0.65
#       4     # Since Python counts from 0 add 1 so machine numbers are accurate
#       5     i = i + 1
#
# NameError: name 'sensorData' is not defined
